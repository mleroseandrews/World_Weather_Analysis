# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs =  zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 770

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from Config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b285451e467c16fb781b092c73f8e73

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]   
        weather_desc = city_weather["weather"][0]["description"]    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Weather" : weather_desc 
                         })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | limulunga
# Processing Record 2 of Set 1 | tres arroyos
# Processing Record 3 of Set 1 | tikrit
# Processing Record 4 of Set 1 | san buenaventura
# Processing Record 5 of Set 1 | aykhal
# Processing Record 6 of Set 1 | veraval
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | norman wells
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | havoysund
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | grafton
# Processing Record 16 of Set 1 | djambala
# Processing Record 17 of Set 1 | pandan niog
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 1 | puerto narino
# Processing Record 21 of Set 1 | narsaq
# Processing Record 22 of Set 1 | tasiilaq
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | cidreira
# Processing Record 26 of Set 1 | kuybysheve
# Processing Record 27 of Set 1 | raga
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | ghanzi
# Processing Record 30 of Set 1 | touros
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | port blair
# Processing Record 33 of Set 1 | hilo
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | aklavik
# Processing Record 36 of Set 1 | nuuk
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | atasu
# Processing Record 39 of Set 1 | laredo
# Processing Record 40 of Set 1 | along
# Processing Record 41 of Set 1 | jumla
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | lavrentiya
# Processing Record 45 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 46 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 1 | pisco
# Processing Record 48 of Set 1 | salekhard
# Processing Record 49 of Set 1 | krasnoselkup
# Processing Record 50 of Set 1 | laguna
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | tabuk
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | umba
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | viedma
# Processing Record 11 of Set 2 | bambous virieux
# Processing Record 12 of Set 2 | san quintin
# Processing Record 13 of Set 2 | kavieng
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | paamiut
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | saint george
# Processing Record 19 of Set 2 | ranong
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | sao borja
# Processing Record 22 of Set 2 | samana
# Processing Record 23 of Set 2 | hithadhoo
# Processing Record 24 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 2 | sisimiut
# Processing Record 26 of Set 2 | tarko-sale
# Processing Record 27 of Set 2 | yar-sale
# Processing Record 28 of Set 2 | namatanai
# Processing Record 29 of Set 2 | bethel
# Processing Record 30 of Set 2 | cabo san lucas
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | fortuna
# Processing Record 33 of Set 2 | nyurba
# Processing Record 34 of Set 2 | antalaha
# Processing Record 35 of Set 2 | jaroslaw
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | lasa
# Processing Record 38 of Set 2 | seymchan
# Processing Record 39 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 2 | hay river
# Processing Record 41 of Set 2 | samarai
# Processing Record 42 of Set 2 | klaksvik
# Processing Record 43 of Set 2 | goderich
# Processing Record 44 of Set 2 | provideniya
# Processing Record 45 of Set 2 | gibara
# Processing Record 46 of Set 2 | lagoa
# Processing Record 47 of Set 2 | pevek
# Processing Record 48 of Set 2 | ixtapa
# Processing Record 49 of Set 2 | finschhafen
# Processing Record 50 of Set 2 | bubaque
# Processing Record 1 of Set 3 | nishihara
# Processing Record 2 of Set 3 | kalmunai
# Processing Record 3 of Set 3 | olafsvik
# Processing Record 4 of Set 3 | port augusta
# Processing Record 5 of Set 3 | avarua
# Processing Record 6 of Set 3 | sao filipe
# Processing Record 7 of Set 3 | hervey bay
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | ferme-neuve
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | port hedland
# Processing Record 13 of Set 3 | bengkulu
# Processing Record 14 of Set 3 | mitsamiouli
# Processing Record 15 of Set 3 | lielvarde
# Processing Record 16 of Set 3 | lompoc
# Processing Record 17 of Set 3 | kachikau
# City not found. Skipping...
# Processing Record 18 of Set 3 | sao joao da barra
# Processing Record 19 of Set 3 | namibe
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | pacific grove
# Processing Record 23 of Set 3 | shar
# Processing Record 24 of Set 3 | jhajjar
# Processing Record 25 of Set 3 | cabedelo
# Processing Record 26 of Set 3 | isangel
# Processing Record 27 of Set 3 | mehamn
# Processing Record 28 of Set 3 | merauke
# Processing Record 29 of Set 3 | bosconia
# Processing Record 30 of Set 3 | fairbanks
# Processing Record 31 of Set 3 | nadapuram
# Processing Record 32 of Set 3 | north bend
# Processing Record 33 of Set 3 | coquimbo
# Processing Record 34 of Set 3 | airai
# Processing Record 35 of Set 3 | havelock
# Processing Record 36 of Set 3 | ojinaga
# Processing Record 37 of Set 3 | peruibe
# Processing Record 38 of Set 3 | banda aceh
# Processing Record 39 of Set 3 | eskasem
# City not found. Skipping...
# Processing Record 40 of Set 3 | salacgriva
# Processing Record 41 of Set 3 | itarema
# Processing Record 42 of Set 3 | bredasdorp
# Processing Record 43 of Set 3 | dongkan
# Processing Record 44 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 3 | torbay
# Processing Record 46 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 3 | margate
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | ancud
# Processing Record 50 of Set 3 | yendi
# Processing Record 1 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 4 | baragua
# Processing Record 3 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 4 | buariki
# City not found. Skipping...
# Processing Record 5 of Set 4 | pouebo
# Processing Record 6 of Set 4 | trelew
# Processing Record 7 of Set 4 | adrar
# Processing Record 8 of Set 4 | grimari
# City not found. Skipping...
# Processing Record 9 of Set 4 | george town
# Processing Record 10 of Set 4 | divnomorskoye
# Processing Record 11 of Set 4 | lata
# Processing Record 12 of Set 4 | los llanos de aridane
# Processing Record 13 of Set 4 | barao de melgaco
# Processing Record 14 of Set 4 | embu
# Processing Record 15 of Set 4 | shiraz
# Processing Record 16 of Set 4 | mount gambier
# Processing Record 17 of Set 4 | sibolga
# Processing Record 18 of Set 4 | china
# Processing Record 19 of Set 4 | boguchany
# Processing Record 20 of Set 4 | asyut
# Processing Record 21 of Set 4 | luderitz
# Processing Record 22 of Set 4 | meulaboh
# Processing Record 23 of Set 4 | velikie luki
# City not found. Skipping...
# Processing Record 24 of Set 4 | mattru
# Processing Record 25 of Set 4 | kruisfontein
# Processing Record 26 of Set 4 | shenjiamen
# Processing Record 27 of Set 4 | chuy
# Processing Record 28 of Set 4 | chokurdakh
# Processing Record 29 of Set 4 | mahebourg
# Processing Record 30 of Set 4 | lagos
# Processing Record 31 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 4 | nabire
# Processing Record 33 of Set 4 | bulgan
# Processing Record 34 of Set 4 | suntar
# Processing Record 35 of Set 4 | fort nelson
# Processing Record 36 of Set 4 | bhawanigarh
# Processing Record 37 of Set 4 | norden
# Processing Record 38 of Set 4 | benghazi
# Processing Record 39 of Set 4 | naze
# Processing Record 40 of Set 4 | carnarvon
# Processing Record 41 of Set 4 | kasongo-lunda
# Processing Record 42 of Set 4 | sorland
# Processing Record 43 of Set 4 | mareeba
# Processing Record 44 of Set 4 | kochubey
# Processing Record 45 of Set 4 | palauig
# Processing Record 46 of Set 4 | kidal
# Processing Record 47 of Set 4 | pokhara
# Processing Record 48 of Set 4 | watsa
# Processing Record 49 of Set 4 | ostrovnoy
# Processing Record 50 of Set 4 | miguel hidalgo
# Processing Record 1 of Set 5 | sioux lookout
# Processing Record 2 of Set 5 | krk
# Processing Record 3 of Set 5 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 4 of Set 5 | dolores
# Processing Record 5 of Set 5 | port alfred
# Processing Record 6 of Set 5 | esperance
# Processing Record 7 of Set 5 | tabou
# Processing Record 8 of Set 5 | cherskiy
# Processing Record 9 of Set 5 | kodinsk
# Processing Record 10 of Set 5 | itaqui
# Processing Record 11 of Set 5 | saint-francois
# Processing Record 12 of Set 5 | ust-uda
# Processing Record 13 of Set 5 | severo-kurilsk
# Processing Record 14 of Set 5 | mackay
# Processing Record 15 of Set 5 | tuatapere
# Processing Record 16 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 5 | hami
# Processing Record 18 of Set 5 | faanui
# Processing Record 19 of Set 5 | araceli
# Processing Record 20 of Set 5 | pokaran
# Processing Record 21 of Set 5 | murmashi
# Processing Record 22 of Set 5 | kaohsiung
# Processing Record 23 of Set 5 | comodoro rivadavia
# Processing Record 24 of Set 5 | buraydah
# Processing Record 25 of Set 5 | henties bay
# Processing Record 26 of Set 5 | saint-pierre
# Processing Record 27 of Set 5 | hanna
# Processing Record 28 of Set 5 | pishin
# Processing Record 29 of Set 5 | coihaique
# Processing Record 30 of Set 5 | nizwa
# Processing Record 31 of Set 5 | bathsheba
# Processing Record 32 of Set 5 | brae
# Processing Record 33 of Set 5 | elk city
# Processing Record 34 of Set 5 | victoria
# Processing Record 35 of Set 5 | haldibari
# Processing Record 36 of Set 5 | rabo de peixe
# Processing Record 37 of Set 5 | vestmannaeyjar
# Processing Record 38 of Set 5 | san patricio
# Processing Record 39 of Set 5 | balakhninskiy
# Processing Record 40 of Set 5 | tutoia
# Processing Record 41 of Set 5 | kangaatsiaq
# Processing Record 42 of Set 5 | lebu
# Processing Record 43 of Set 5 | kenai
# Processing Record 44 of Set 5 | doha
# Processing Record 45 of Set 5 | coahuayana
# Processing Record 46 of Set 5 | muli
# Processing Record 47 of Set 5 | northam
# Processing Record 48 of Set 5 | ilulissat
# Processing Record 49 of Set 5 | tessalit
# Processing Record 50 of Set 5 | salinas
# Processing Record 1 of Set 6 | north platte
# Processing Record 2 of Set 6 | ust-ishim
# Processing Record 3 of Set 6 | vao
# Processing Record 4 of Set 6 | vanavara
# Processing Record 5 of Set 6 | omboue
# Processing Record 6 of Set 6 | bandarbeyla
# Processing Record 7 of Set 6 | arcachon
# Processing Record 8 of Set 6 | solnechnyy
# Processing Record 9 of Set 6 | la trinitaria
# Processing Record 10 of Set 6 | caconda
# Processing Record 11 of Set 6 | alofi
# Processing Record 12 of Set 6 | east london
# Processing Record 13 of Set 6 | puerto colombia
# Processing Record 14 of Set 6 | tual
# Processing Record 15 of Set 6 | kaitangata
# Processing Record 16 of Set 6 | kaabong
# Processing Record 17 of Set 6 | lima
# Processing Record 18 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 6 | palmer
# Processing Record 20 of Set 6 | leningradskiy
# Processing Record 21 of Set 6 | mwense
# Processing Record 22 of Set 6 | pandamatenga
# Processing Record 23 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 24 of Set 6 | saskylakh
# Processing Record 25 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 6 | santa maria del oro
# Processing Record 28 of Set 6 | nanortalik
# Processing Record 29 of Set 6 | nikolskoye
# Processing Record 30 of Set 6 | katsuura
# Processing Record 31 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 32 of Set 6 | shushtar
# Processing Record 33 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 6 | cheremshan
# Processing Record 35 of Set 6 | bereda
# Processing Record 36 of Set 6 | sabang
# Processing Record 37 of Set 6 | kolyshley
# Processing Record 38 of Set 6 | eyl
# Processing Record 39 of Set 6 | nchelenge
# Processing Record 40 of Set 6 | arusha
# Processing Record 41 of Set 6 | yichun
# Processing Record 42 of Set 6 | komsomolskiy
# Processing Record 43 of Set 6 | ahipara
# Processing Record 44 of Set 6 | faya
# Processing Record 45 of Set 6 | ponta do sol
# Processing Record 46 of Set 6 | sernur
# Processing Record 47 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 6 | charlestown
# Processing Record 49 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 6 | hamilton
# Processing Record 1 of Set 7 | asau
# Processing Record 2 of Set 7 | the valley
# Processing Record 3 of Set 7 | nyimba
# Processing Record 4 of Set 7 | plettenberg bay
# Processing Record 5 of Set 7 | georgetown
# Processing Record 6 of Set 7 | konya
# Processing Record 7 of Set 7 | cayenne
# Processing Record 8 of Set 7 | kargasok
# Processing Record 9 of Set 7 | nurota
# Processing Record 10 of Set 7 | broken hill
# Processing Record 11 of Set 7 | tucupita
# Processing Record 12 of Set 7 | tayu
# Processing Record 13 of Set 7 | tura
# Processing Record 14 of Set 7 | wuning
# Processing Record 15 of Set 7 | kununurra
# Processing Record 16 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 7 | san policarpo
# Processing Record 18 of Set 7 | eureka
# Processing Record 19 of Set 7 | broome
# Processing Record 20 of Set 7 | rio gallegos
# Processing Record 21 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 7 | gull lake
# Processing Record 23 of Set 7 | oksfjord
# Processing Record 24 of Set 7 | zabaykalsk
# Processing Record 25 of Set 7 | yeppoon
# Processing Record 26 of Set 7 | aasiaat
# Processing Record 27 of Set 7 | sembe
# Processing Record 28 of Set 7 | kattivakkam
# Processing Record 29 of Set 7 | feuchtwangen
# Processing Record 30 of Set 7 | inhambane
# Processing Record 31 of Set 7 | thasra
# Processing Record 32 of Set 7 | waingapu
# Processing Record 33 of Set 7 | auki
# Processing Record 34 of Set 7 | seoul
# Processing Record 35 of Set 7 | hirado
# Processing Record 36 of Set 7 | malinovoye ozero
# Processing Record 37 of Set 7 | gidam
# Processing Record 38 of Set 7 | black river
# Processing Record 39 of Set 7 | camacha
# Processing Record 40 of Set 7 | baherden
# Processing Record 41 of Set 7 | maniitsoq
# Processing Record 42 of Set 7 | sharjah
# Processing Record 43 of Set 7 | mayo
# Processing Record 44 of Set 7 | hovd
# Processing Record 45 of Set 7 | new amsterdam
# Processing Record 46 of Set 7 | labuhan
# Processing Record 47 of Set 7 | neiafu
# Processing Record 48 of Set 7 | dodoma
# Processing Record 49 of Set 7 | tenamaxtlan
# Processing Record 50 of Set 7 | linguere
# Processing Record 1 of Set 8 | tomohon
# Processing Record 2 of Set 8 | haines junction
# Processing Record 3 of Set 8 | privolnyy
# Processing Record 4 of Set 8 | lorengau
# Processing Record 5 of Set 8 | umm kaddadah
# Processing Record 6 of Set 8 | vila
# Processing Record 7 of Set 8 | ketchikan
# Processing Record 8 of Set 8 | kungurtug
# Processing Record 9 of Set 8 | cedar city
# Processing Record 10 of Set 8 | codrington
# Processing Record 11 of Set 8 | imeni poliny osipenko
# Processing Record 12 of Set 8 | caravelas
# Processing Record 13 of Set 8 | evensk
# Processing Record 14 of Set 8 | yulara
# Processing Record 15 of Set 8 | orange
# Processing Record 16 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 17 of Set 8 | krutikha
# Processing Record 18 of Set 8 | port hardy
# Processing Record 19 of Set 8 | baruun-urt
# Processing Record 20 of Set 8 | arraial do cabo
# Processing Record 21 of Set 8 | puerto ayacucho
# Processing Record 22 of Set 8 | mangai
# Processing Record 23 of Set 8 | sobolevo
# Processing Record 24 of Set 8 | kholm
# Processing Record 25 of Set 8 | praia
# Processing Record 26 of Set 8 | great malvern
# Processing Record 27 of Set 8 | pau brasil
# Processing Record 28 of Set 8 | panzhihua
# Processing Record 29 of Set 8 | port lincoln
# Processing Record 30 of Set 8 | geraldton
# Processing Record 31 of Set 8 | alta floresta
# Processing Record 32 of Set 8 | padang
# Processing Record 33 of Set 8 | saint-philippe
# Processing Record 34 of Set 8 | sao joao do piaui
# Processing Record 35 of Set 8 | ryotsu
# Processing Record 36 of Set 8 | wanning
# Processing Record 37 of Set 8 | mutoko
# Processing Record 38 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 8 | shawnee
# Processing Record 40 of Set 8 | korla
# Processing Record 41 of Set 8 | yatou
# Processing Record 42 of Set 8 | kangema
# Processing Record 43 of Set 8 | scarborough
# Processing Record 44 of Set 8 | hofn
# Processing Record 45 of Set 8 | yaqui
# Processing Record 46 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 8 | byron bay
# Processing Record 48 of Set 8 | gizo
# Processing Record 49 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 50 of Set 8 | krasnyye tkachi
# Processing Record 1 of Set 9 | caramay
# Processing Record 2 of Set 9 | hit
# Processing Record 3 of Set 9 | dekoa
# City not found. Skipping...
# Processing Record 4 of Set 9 | udachnyy
# Processing Record 5 of Set 9 | sangar
# Processing Record 6 of Set 9 | jasper
# Processing Record 7 of Set 9 | aitape
# Processing Record 8 of Set 9 | beysehir
# Processing Record 9 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 10 of Set 9 | atyuryevo
# City not found. Skipping...
# Processing Record 11 of Set 9 | amuntai
# Processing Record 12 of Set 9 | muzhi
# Processing Record 13 of Set 9 | ambon
# Processing Record 14 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 15 of Set 9 | wagar
# Processing Record 16 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 17 of Set 9 | markova
# Processing Record 18 of Set 9 | abu dhabi
# Processing Record 19 of Set 9 | rawson
# Processing Record 20 of Set 9 | nome
# Processing Record 21 of Set 9 | longyearbyen
# Processing Record 22 of Set 9 | yerbogachen
# Processing Record 23 of Set 9 | la ronge
# Processing Record 24 of Set 9 | hasaki
# Processing Record 25 of Set 9 | kortkeros
# Processing Record 26 of Set 9 | te anau
# Processing Record 27 of Set 9 | salalah
# Processing Record 28 of Set 9 | rincon
# Processing Record 29 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 9 | jinji
# Processing Record 31 of Set 9 | kourou
# Processing Record 32 of Set 9 | sibu
# Processing Record 33 of Set 9 | mao
# Processing Record 34 of Set 9 | uray
# Processing Record 35 of Set 9 | rognan
# Processing Record 36 of Set 9 | flinders
# Processing Record 37 of Set 9 | tezu
# Processing Record 38 of Set 9 | kamenka
# Processing Record 39 of Set 9 | santa clarita
# Processing Record 40 of Set 9 | las guacamayas
# Processing Record 41 of Set 9 | clyde river
# Processing Record 42 of Set 9 | thinadhoo
# Processing Record 43 of Set 9 | zig
# Processing Record 44 of Set 9 | boke
# Processing Record 45 of Set 9 | vostok
# Processing Record 46 of Set 9 | salamiyah
# Processing Record 47 of Set 9 | indramayu
# Processing Record 48 of Set 9 | hobyo
# Processing Record 49 of Set 9 | sistranda
# Processing Record 50 of Set 9 | qui nhon
# Processing Record 1 of Set 10 | gunjur
# Processing Record 2 of Set 10 | praya
# Processing Record 3 of Set 10 | awjilah
# Processing Record 4 of Set 10 | balkhash
# Processing Record 5 of Set 10 | lerwick
# Processing Record 6 of Set 10 | half moon bay
# Processing Record 7 of Set 10 | san cristobal
# Processing Record 8 of Set 10 | guiratinga
# Processing Record 9 of Set 10 | umm lajj
# Processing Record 10 of Set 10 | vite
# Processing Record 11 of Set 10 | taksimo
# Processing Record 12 of Set 10 | chipoka
# Processing Record 13 of Set 10 | anahuac
# Processing Record 14 of Set 10 | burnie
# Processing Record 15 of Set 10 | contai
# Processing Record 16 of Set 10 | lac du bonnet
# Processing Record 17 of Set 10 | sabla
# Processing Record 18 of Set 10 | iquique
# Processing Record 19 of Set 10 | hokitika
# Processing Record 20 of Set 10 | chandia
# Processing Record 21 of Set 10 | rochegda
# Processing Record 22 of Set 10 | jiwani
# Processing Record 23 of Set 10 | lunino
# Processing Record 24 of Set 10 | tambura
# Processing Record 25 of Set 10 | atar
# Processing Record 26 of Set 10 | kifri
# Processing Record 27 of Set 10 | kailua
# Processing Record 28 of Set 10 | bozeman
# Processing Record 29 of Set 10 | mukhen
# Processing Record 30 of Set 10 | okha
# Processing Record 31 of Set 10 | praia da vitoria
# Processing Record 32 of Set 10 | sinop
# Processing Record 33 of Set 10 | rio branco
# Processing Record 34 of Set 10 | garoua
# Processing Record 35 of Set 10 | cururupu
# Processing Record 36 of Set 10 | sitka
# Processing Record 37 of Set 10 | zhigansk
# Processing Record 38 of Set 10 | saint-ambroise
# Processing Record 39 of Set 10 | dingle
# Processing Record 40 of Set 10 | la orilla
# Processing Record 41 of Set 10 | caldas de vizela
# Processing Record 42 of Set 10 | astoria
# Processing Record 43 of Set 10 | mansehra
# Processing Record 44 of Set 10 | fargo
# Processing Record 45 of Set 10 | puri
# Processing Record 46 of Set 10 | bocana de paiwas
# Processing Record 47 of Set 10 | tigil
# Processing Record 48 of Set 10 | srednekolymsk
# Processing Record 49 of Set 10 | san nicolas
# Processing Record 50 of Set 10 | calama
# Processing Record 1 of Set 11 | pousat
# City not found. Skipping...
# Processing Record 2 of Set 11 | la baule-escoublac
# Processing Record 3 of Set 11 | zhangjiakou
# Processing Record 4 of Set 11 | puro
# Processing Record 5 of Set 11 | leshukonskoye
# Processing Record 6 of Set 11 | kathmandu
# Processing Record 7 of Set 11 | karnobat
# Processing Record 8 of Set 11 | massakory
# Processing Record 9 of Set 11 | rockland
# Processing Record 10 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 11 | ramon
# Processing Record 12 of Set 11 | huarmey
# Processing Record 13 of Set 11 | waconia
# Processing Record 14 of Set 11 | fasa
# Processing Record 15 of Set 11 | tukrah
# Processing Record 16 of Set 11 | moussoro
# Processing Record 17 of Set 11 | ljubinje
# Processing Record 18 of Set 11 | anlu
# Processing Record 19 of Set 11 | vanimo
# Processing Record 20 of Set 11 | sao jose dos pinhais
# Processing Record 21 of Set 11 | bundaberg
# Processing Record 22 of Set 11 | iqaluit
# Processing Record 23 of Set 11 | patratu
# City not found. Skipping...
# Processing Record 24 of Set 11 | saldanha
# Processing Record 25 of Set 11 | college
# Processing Record 26 of Set 11 | vardo
# Processing Record 27 of Set 11 | selenduma
# Processing Record 28 of Set 11 | portoferraio
# Processing Record 29 of Set 11 | del rio
# Processing Record 30 of Set 11 | bonavista
# Processing Record 31 of Set 11 | madulao
# Processing Record 32 of Set 11 | avera
# Processing Record 33 of Set 11 | sadiqabad
# Processing Record 34 of Set 11 | ouegoa
# Processing Record 35 of Set 11 | moryakovskiy zaton
# Processing Record 36 of Set 11 | eyrarbakki
# Processing Record 37 of Set 11 | oytal
# Processing Record 38 of Set 11 | murray bridge
# Processing Record 39 of Set 11 | kovdor
# Processing Record 40 of Set 11 | vaitape
# Processing Record 41 of Set 11 | svistov
# City not found. Skipping...
# Processing Record 42 of Set 11 | tete
# Processing Record 43 of Set 11 | cornwall
# Processing Record 44 of Set 11 | guerrero negro
# Processing Record 45 of Set 11 | abha
# Processing Record 46 of Set 11 | sakakah
# Processing Record 47 of Set 11 | paita
# Processing Record 48 of Set 11 | kangasala
# Processing Record 49 of Set 11 | salina cruz
# Processing Record 50 of Set 11 | ust-nera
# Processing Record 1 of Set 12 | marawi
# Processing Record 2 of Set 12 | nadym
# Processing Record 3 of Set 12 | bafq
# Processing Record 4 of Set 12 | khilok
# Processing Record 5 of Set 12 | jizan
# Processing Record 6 of Set 12 | rabak
# Processing Record 7 of Set 12 | itoman
# Processing Record 8 of Set 12 | husavik
# Processing Record 9 of Set 12 | cap malheureux
# Processing Record 10 of Set 12 | unguia
# Processing Record 11 of Set 12 | arden
# Processing Record 12 of Set 12 | moerai
# Processing Record 13 of Set 12 | dabat
# Processing Record 14 of Set 12 | khasan
# Processing Record 15 of Set 12 | bolotnoye
# Processing Record 16 of Set 12 | tauramena
# Processing Record 17 of Set 12 | quang ngai
# Processing Record 18 of Set 12 | jevargi
# Processing Record 19 of Set 12 | marrakesh
# Processing Record 20 of Set 12 | dwarka
# Processing Record 21 of Set 12 | kapoeta
# Processing Record 22 of Set 12 | abonnema
# Processing Record 23 of Set 12 | aripuana
# Processing Record 24 of Set 12 | bela cruz
# Processing Record 25 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 12 | luxor
# Processing Record 28 of Set 12 | lyubim
# Processing Record 29 of Set 12 | kieta
# Processing Record 30 of Set 12 | bara
# Processing Record 31 of Set 12 | jablah
# Processing Record 32 of Set 12 | chipinge
# Processing Record 33 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 12 | ploufragan
# Processing Record 35 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 36 of Set 12 | fontem
# Processing Record 37 of Set 12 | uige
# Processing Record 38 of Set 12 | marzuq
# Processing Record 39 of Set 12 | pangnirtung
# Processing Record 40 of Set 12 | erenhot
# Processing Record 41 of Set 12 | matagami
# Processing Record 42 of Set 12 | monrovia
# Processing Record 43 of Set 12 | kidero
# Processing Record 44 of Set 12 | paulo afonso
# Processing Record 45 of Set 12 | shenzhen
# Processing Record 46 of Set 12 | cece
# Processing Record 47 of Set 12 | nichinan
# Processing Record 48 of Set 12 | safakulevo
# Processing Record 49 of Set 12 | khorramshahr
# Processing Record 50 of Set 12 | santander
# Processing Record 1 of Set 13 | thompson
# Processing Record 2 of Set 13 | carballo
# Processing Record 3 of Set 13 | san andres
# Processing Record 4 of Set 13 | pimentel
# Processing Record 5 of Set 13 | san sebastian
# Processing Record 6 of Set 13 | zhezkazgan
# Processing Record 7 of Set 13 | nakhon thai
# Processing Record 8 of Set 13 | akhisar
# Processing Record 9 of Set 13 | omsukchan
# Processing Record 10 of Set 13 | bonnyville
# Processing Record 11 of Set 13 | anadyr
# Processing Record 12 of Set 13 | rio grande
# Processing Record 13 of Set 13 | olivenza
# Processing Record 14 of Set 13 | taoudenni
# Processing Record 15 of Set 13 | talnakh
# Processing Record 16 of Set 13 | sucre
# Processing Record 17 of Set 13 | xining
# Processing Record 18 of Set 13 | kota kinabalu
# Processing Record 19 of Set 13 | baoning
# Processing Record 20 of Set 13 | mecca
# Processing Record 21 of Set 13 | san antonio
# Processing Record 22 of Set 13 | san lorenzo
# Processing Record 23 of Set 13 | bam
# Processing Record 24 of Set 13 | gumdag
# Processing Record 25 of Set 13 | champerico
# Processing Record 26 of Set 13 | santiago del estero
# Processing Record 27 of Set 13 | baicheng
# Processing Record 28 of Set 13 | najran
# Processing Record 29 of Set 13 | richards bay
# Processing Record 30 of Set 13 | kushima
# Processing Record 31 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 13 | arouca
# Processing Record 33 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 34 of Set 13 | ploemeur
# Processing Record 35 of Set 13 | bloemfontein
# Processing Record 36 of Set 13 | markivka
# Processing Record 37 of Set 13 | nicoya
# Processing Record 38 of Set 13 | nioro
# Processing Record 39 of Set 13 | manokwari
# Processing Record 40 of Set 13 | ilhabela
# Processing Record 41 of Set 13 | ranot
# Processing Record 42 of Set 13 | quatre cocos
# Processing Record 43 of Set 13 | mitchell
# Processing Record 44 of Set 13 | pringsewu
# Processing Record 45 of Set 13 | da nang
# Processing Record 46 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 13 | almaznyy
# Processing Record 48 of Set 13 | key west
# Processing Record 49 of Set 13 | kutum
# Processing Record 50 of Set 13 | port-gentil
# Processing Record 1 of Set 14 | san jeronimo
# Processing Record 2 of Set 14 | puerto princesa
# Processing Record 3 of Set 14 | luoyang
# Processing Record 4 of Set 14 | chumphon
# Processing Record 5 of Set 14 | batagay
# Processing Record 6 of Set 14 | port macquarie
# Processing Record 7 of Set 14 | dumas
# Processing Record 8 of Set 14 | portel
# Processing Record 9 of Set 14 | puntarenas
# Processing Record 10 of Set 14 | minab
# Processing Record 11 of Set 14 | muscat
# Processing Record 12 of Set 14 | elat
# Processing Record 13 of Set 14 | christchurch
# Processing Record 14 of Set 14 | tocantinopolis
# City not found. Skipping...
# Processing Record 15 of Set 14 | guia lopes da laguna
# Processing Record 16 of Set 14 | jaipur hat
# City not found. Skipping...
# Processing Record 17 of Set 14 | stykkisholmur
# Processing Record 18 of Set 14 | minna
# Processing Record 19 of Set 14 | acarau
# Processing Record 20 of Set 14 | lalomanu
# City not found. Skipping...
# Processing Record 21 of Set 14 | vikhorevka
# Processing Record 22 of Set 14 | kalachinsk
# Processing Record 23 of Set 14 | botucatu
# Processing Record 24 of Set 14 | marsaxlokk
# Processing Record 25 of Set 14 | divo
# Processing Record 26 of Set 14 | oranjemund
# Processing Record 27 of Set 14 | trairi
# Processing Record 28 of Set 14 | charters towers
# Processing Record 29 of Set 14 | honiara
# Processing Record 30 of Set 14 | lovozero
# Processing Record 31 of Set 14 | gawler
# Processing Record 32 of Set 14 | lampa
# Processing Record 33 of Set 14 | valparaiso
# Processing Record 34 of Set 14 | acajutla
# Processing Record 35 of Set 14 | zaysan
# Processing Record 36 of Set 14 | pochutla
# Processing Record 37 of Set 14 | grand gaube
# Processing Record 38 of Set 14 | cape canaveral
# Processing Record 39 of Set 14 | leninskoye
# Processing Record 40 of Set 14 | bluefield
# Processing Record 41 of Set 14 | estreito
# Processing Record 42 of Set 14 | nenjiang
# Processing Record 43 of Set 14 | dongsheng
# Processing Record 44 of Set 14 | awbari
# Processing Record 45 of Set 14 | jian
# Processing Record 46 of Set 14 | mount hagen
# Processing Record 47 of Set 14 | ambovombe
# Processing Record 48 of Set 14 | orthez
# Processing Record 49 of Set 14 | livingston
# Processing Record 50 of Set 14 | pathein
# Processing Record 1 of Set 15 | deputatskiy
# Processing Record 2 of Set 15 | berlin
# Processing Record 3 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 15 | oranzherei
# Processing Record 5 of Set 15 | vila franca do campo
# Processing Record 6 of Set 15 | novyye burasy
# Processing Record 7 of Set 15 | saquena
# Processing Record 8 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 15 | cabra
# Processing Record 10 of Set 15 | hare bay
# Processing Record 11 of Set 15 | shimoda
# Processing Record 12 of Set 15 | zhanjiang
# Processing Record 13 of Set 15 | ballina
# Processing Record 14 of Set 15 | muisne
# Processing Record 15 of Set 15 | teshie
# Processing Record 16 of Set 15 | hatillo
# Processing Record 17 of Set 15 | neuquen
# Processing Record 18 of Set 15 | taybad
# Processing Record 19 of Set 15 | linxi
# Processing Record 20 of Set 15 | keffi
# Processing Record 21 of Set 15 | salinopolis
# Processing Record 22 of Set 15 | karakol
# Processing Record 23 of Set 15 | shingu
# Processing Record 24 of Set 15 | santa cruz de tenerife
# Processing Record 25 of Set 15 | garmsar
# Processing Record 26 of Set 15 | grand forks
# Processing Record 27 of Set 15 | vestmanna
# Processing Record 28 of Set 15 | cayeli
# Processing Record 29 of Set 15 | yeniseysk
# Processing Record 30 of Set 15 | chiang klang
# Processing Record 31 of Set 15 | annau
# Processing Record 32 of Set 15 | salamanca
# Processing Record 33 of Set 15 | gualeguay
# Processing Record 34 of Set 15 | muhos
# Processing Record 35 of Set 15 | newport
# Processing Record 36 of Set 15 | pionerskiy
# Processing Record 37 of Set 15 | sur
# Processing Record 38 of Set 15 | berdavan
# Processing Record 39 of Set 15 | maldonado
# Processing Record 40 of Set 15 | xai-xai
# Processing Record 41 of Set 15 | el balyana
# City not found. Skipping...
# Processing Record 42 of Set 15 | maxixe
# Processing Record 43 of Set 15 | sungaipenuh
# Processing Record 44 of Set 15 | azul
# Processing Record 45 of Set 15 | arlit
# Processing Record 46 of Set 15 | puerto madryn
# Processing Record 47 of Set 15 | ust-kan
# Processing Record 48 of Set 15 | mutsu
# Processing Record 49 of Set 15 | visnes
# Processing Record 50 of Set 15 | dunedin
# Processing Record 1 of Set 16 | puttur
# Processing Record 2 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 16 | pangoa
# Processing Record 4 of Set 16 | kahului
# Processing Record 5 of Set 16 | manadhoo
# Processing Record 6 of Set 16 | ganzhou
# Processing Record 7 of Set 16 | jiroft
# City not found. Skipping...
# Processing Record 8 of Set 16 | saint-augustin
# Processing Record 9 of Set 16 | mortka
# Processing Record 10 of Set 16 | zhangye
# Processing Record 11 of Set 16 | primero de enero
# Processing Record 12 of Set 16 | mae sai
# Processing Record 13 of Set 16 | phonhong
# Processing Record 14 of Set 16 | alice springs
# Processing Record 15 of Set 16 | kloulklubed
# Processing Record 16 of Set 16 | vientiane
# Processing Record 17 of Set 16 | young
# Processing Record 18 of Set 16 | chama
# Processing Record 19 of Set 16 | semnan
# Processing Record 20 of Set 16 | vetluga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 712

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Limulunga -15.0969   23.1376     66.22        92          65
# 1      Tres Arroyos -38.3739  -60.2798     73.60        22           0
# 2            Tikrit  34.6071   43.6782     55.92        56           5
# 3  San Buenaventura  27.0833 -101.5333     71.47        68           0
# 4            Aykhal  66.0000  111.5000    -16.64        92         100
# 5           Veraval  20.9000   70.3667     68.63        38          64
# 6             Kapaa  22.0752 -159.3190     82.38        74         100
# 7      Norman Wells  65.2820 -126.8329    -21.96        76          75
# 8            Hobart -42.8794  147.3294     60.26        73          75
# 9            Albany  42.6001  -73.9662     37.67        77          35
#
#    Wind Speed Country   Current Weather
# 0        5.03      ZM        light rain
# 1        8.46      AR         clear sky
# 2        6.78      IQ         clear sky
# 3        5.50      MX         clear sky
# 4        4.00      RU   overcast clouds
# 5       11.81      IN     broken clouds
# 6        7.00      US   overcast clouds
# 7        0.00      CA     broken clouds
# 8       17.27      AU     broken clouds
# 9        1.01      US  scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Weather'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", 
                    "Country",
                    "Lat",
                    "Lng",
                    "Max Temp",
                    "Humidity",
                    "Cloudiness",
                    "Wind Speed",
                    "Current Weather"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Limulunga      ZM -15.0969   23.1376     66.22        92
# 1      Tres Arroyos      AR -38.3739  -60.2798     73.60        22
# 2            Tikrit      IQ  34.6071   43.6782     55.92        56
# 3  San Buenaventura      MX  27.0833 -101.5333     71.47        68
# 4            Aykhal      RU  66.0000  111.5000    -16.64        92
#
#    Cloudiness  Wind Speed  Current Weather
# 0          65        5.03       light rain
# 1           0        8.46        clear sky
# 2           5        6.78        clear sky
# 3           0        5.50        clear sky
# 4         100        4.00  overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                object
# Country             object
# Lat                float64
# Lng                float64
# Max Temp           float64
# Humidity             int64
# Cloudiness           int64
# Wind Speed         float64
# Current Weather     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
