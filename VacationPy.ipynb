# %%
# Import the required libraries
import hvplot.pandas
import pandas as pd

# %%
# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0          Hilo  19.7297 -155.0900     79.29        89         100
# 1        1       Ushuaia -54.8000  -68.3000     47.86        49          40
# 2        2  Punta Arenas -53.1500  -70.9167     48.31        53           0
# 3        3     Busselton -33.6500  115.3333     62.58        72          53
# 4        4       Qaanaaq  77.4840  -69.3632     11.97        67          83
#
#    Wind Speed Country                 Date
# 0       12.66      US  2022-12-07 22:52:28
# 1       24.16      AR  2022-12-07 22:52:52
# 2       17.27      CL  2022-12-07 22:52:45
# 3        6.29      AU  2022-12-07 22:52:53
# 4        8.41      GL  2022-12-07 22:52:53

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date           object
# dtype: object

# %%
# Configure the map plot_1
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM"
)
# Display the map plot_1
map_plot_1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\util.py in process_crs(crs)
#     229     try:
# --> 230         import cartopy.crs as ccrs
#     231         import geoviews as gv # noqa
#
# ModuleNotFoundError: No module named 'cartopy'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13508\3524805981.py in <module>
#       4     "Lat",
#       5     geo = True,
# ----> 6     tiles = "OSM"
#       7 )
#       8 # Display the map plot_1
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\plotting\core.py in points(self, x, y, **kwds)
#    1188         to learn more about its parameters and options.
#    1189         """
# -> 1190         return self(x, y, kind="points", **kwds)
#    1191
#    1192     def vectorfield(self, x=None, y=None, angle=None, mag=None, **kwds):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\plotting\core.py in __call__(self, x, y, kind, **kwds)
#     128                 return pn.panel(plot, **panel_dict)
#     129
# --> 130         return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#     131
#     132     def _get_converter(self, x=None, y=None, kind=None, **kwds):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\plotting\core.py in _get_converter(self, x, y, kind, **kwds)
#     135         y = y or params.pop("y", None)
#     136         kind = kind or params.pop("kind", None)
# --> 137         return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#     138
#     139     def __dir__(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\converter.py in __init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     394         self.dynamic = dynamic
#     395         self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 396         self.crs = self._process_crs(data, crs) if self.geo else None
#     397         self.project = project
#     398         self.coastline = coastline
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\converter.py in _process_crs(self, data, crs)
#     643         _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     644         try:
# --> 645             return process_crs(_crs)
#     646         except ValueError:
#     647             # only raise error if crs was specified in kwargs
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\util.py in process_crs(crs)
#     232         import pyproj
#     233     except ImportError:
# --> 234         raise ImportError('Geographic projection support requires GeoViews and cartopy.')
#     235
#     236     if crs is None:
#
# ImportError: Geographic projection support requires GeoViews and cartopy.

# %%
# Configure the map plot_2
map_plot_2 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500
)

# Display the map plot
map_plot_2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\util.py in process_crs(crs)
#     229     try:
# --> 230         import cartopy.crs as ccrs
#     231         import geoviews as gv # noqa
#
# ModuleNotFoundError: No module named 'cartopy'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13508\1287107836.py in <module>
#       6     tiles = "OSM",
#       7     frame_width = 700,
# ----> 8     frame_height = 500
#       9 )
#      10
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\plotting\core.py in points(self, x, y, **kwds)
#    1188         to learn more about its parameters and options.
#    1189         """
# -> 1190         return self(x, y, kind="points", **kwds)
#    1191
#    1192     def vectorfield(self, x=None, y=None, angle=None, mag=None, **kwds):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\plotting\core.py in __call__(self, x, y, kind, **kwds)
#     128                 return pn.panel(plot, **panel_dict)
#     129
# --> 130         return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#     131
#     132     def _get_converter(self, x=None, y=None, kind=None, **kwds):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\plotting\core.py in _get_converter(self, x, y, kind, **kwds)
#     135         y = y or params.pop("y", None)
#     136         kind = kind or params.pop("kind", None)
# --> 137         return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#     138
#     139     def __dir__(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\converter.py in __init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     394         self.dynamic = dynamic
#     395         self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 396         self.crs = self._process_crs(data, crs) if self.geo else None
#     397         self.project = project
#     398         self.coastline = coastline
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\converter.py in _process_crs(self, data, crs)
#     643         _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     644         try:
# --> 645             return process_crs(_crs)
#     646         except ValueError:
#     647             # only raise error if crs was specified in kwargs
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\util.py in process_crs(crs)
#     232         import pyproj
#     233     except ImportError:
# --> 234         raise ImportError('Geographic projection support requires GeoViews and cartopy.')
#     235
#     236     if crs is None:
#
# ImportError: Geographic projection support requires GeoViews and cartopy.

# %%
# Configure the map plot_3
map_plot_3 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_3

# %%
# Configure the map plot_4
map_plot_4 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_4

# %%
# Configure the map plot_4
map_plot_4 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    size = "Wind Speed",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_5
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\util.py in process_crs(crs)
#     229     try:
# --> 230         import cartopy.crs as ccrs
#     231         import geoviews as gv # noqa
#
# ModuleNotFoundError: No module named 'cartopy'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13508\1080210611.py in <module>
#       9     size = "Wind Speed",
#      10     scale = 0.5,
# ---> 11     color = "City"
#      12 )
#      13
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\plotting\core.py in points(self, x, y, **kwds)
#    1188         to learn more about its parameters and options.
#    1189         """
# -> 1190         return self(x, y, kind="points", **kwds)
#    1191
#    1192     def vectorfield(self, x=None, y=None, angle=None, mag=None, **kwds):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\plotting\core.py in __call__(self, x, y, kind, **kwds)
#     128                 return pn.panel(plot, **panel_dict)
#     129
# --> 130         return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#     131
#     132     def _get_converter(self, x=None, y=None, kind=None, **kwds):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\plotting\core.py in _get_converter(self, x, y, kind, **kwds)
#     135         y = y or params.pop("y", None)
#     136         kind = kind or params.pop("kind", None)
# --> 137         return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#     138
#     139     def __dir__(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\converter.py in __init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     394         self.dynamic = dynamic
#     395         self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 396         self.crs = self._process_crs(data, crs) if self.geo else None
#     397         self.project = project
#     398         self.coastline = coastline
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\converter.py in _process_crs(self, data, crs)
#     643         _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     644         try:
# --> 645             return process_crs(_crs)
#     646         except ValueError:
#     647             # only raise error if crs was specified in kwargs
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\util.py in process_crs(crs)
#     232         import pyproj
#     233     except ImportError:
# --> 234         raise ImportError('Geographic projection support requires GeoViews and cartopy.')
#     235
#     236     if crs is None:
#
# ImportError: Geographic projection support requires GeoViews and cartopy.

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
preferred_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)
]
preferred_cities_df.head(10)
# Out:
#     City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 0         0             Hilo  19.7297 -155.0900     79.29        89
# 11       11      Santa Maria -29.6842  -53.8069     81.70        54
# 13       13        Hithadhoo  -0.6000   73.0833     81.68        77
# 17       17       Bluefields  12.0137  -83.7635     82.47        78
# 24       24           Faanui -16.4833 -151.7500     80.44        78
# 31       31           Lethem   3.3803  -59.7968     78.10        81
# 35       35       Georgetown   5.4112  100.3354     80.89        88
# 37       37          Kavieng  -2.5744  150.7967     82.35        76
# 38       38            Kapaa  22.0752 -159.3190     79.11        76
# 42       42  Bambous Virieux -20.3428   57.7575     76.21        88
#
#     Cloudiness  Wind Speed Country                 Date
# 0          100       12.66      US  2022-12-07 22:52:28
# 11           0        9.22      BR  2022-12-07 22:51:01
# 13         100       15.32      MV  2022-12-07 22:52:57
# 17          40        6.91      NI  2022-12-07 22:52:58
# 24         100       19.44      PF  2022-12-07 22:53:00
# 31          97        5.32      GY  2022-12-07 22:53:05
# 35          20        8.05      MY  2022-12-07 22:53:07
# 37          86        6.73      PG  2022-12-07 22:53:10
# 38         100        7.00      US  2022-12-07 22:53:11
# 42          75       13.80      MU  2022-12-07 22:53:13

# %%
preferred_cities_df.count()
# Out:
# City_ID       149
# City          149
# Lat           149
# Lng           149
# Max Temp      149
# Humidity      149
# Cloudiness    149
# Wind Speed    149
# Country       148
# Date          149
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp      Lat       Lng Hotel Name
# 0              Hilo      US     79.29  19.7297 -155.0900
# 11      Santa Maria      BR     81.70 -29.6842  -53.8069
# 13        Hithadhoo      MV     81.68  -0.6000   73.0833
# 17       Bluefields      NI     82.47  12.0137  -83.7635
# 24           Faanui      PF     80.44 -16.4833 -151.7500
# 31           Lethem      GY     78.10   3.3803  -59.7968
# 35       Georgetown      MY     80.89   5.4112  100.3354
# 37          Kavieng      PG     82.35  -2.5744  150.7967
# 38            Kapaa      US     79.11  22.0752 -159.3190
# 42  Bambous Virieux      MU     76.21 -20.3428   57.7575

# %%
# Set initial parameters to search for a hotel.
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
}
